# %%
import csv
from collections import defaultdict as ddict

wd = "data/job_offers/" # The directory that the data files are in

print("Recording job locations...")
job_info = {}
data = list()
with open(wd + "jobs.tsv", "r") as infile:
    reader = csv.reader(infile, delimiter="\t", 
    quoting=csv.QUOTE_NONE, quotechar="")
    next(reader) # burn the header
    for line in reader:
        (Jobid, WindowId, Title, Description, Requirements, City, State, 
        Country, Zip5, StartDate, EndDate) = line
        data.append({"Jobid":Jobid, "WindowId": WindowId, "Title": Title, 
                     "Description": Description, 
                     "Requirements": Requirements, 
                     "City":City, 
                     "State": State, 
        "Country": Country, "Zip5": Zip5, "StartDate": StartDate, "EndDate": EndDate})
        job_info[str(Jobid)] = [int(WindowId), State, City, 0]
        # The terminal zero is for an application count

print ("Counting applications...")
with open(wd + "apps.tsv") as infile:
    reader = csv.reader(infile, delimiter="\t")
    next(reader)  # burn the header
    for line in reader:
        (UserId, WindowID, Split, ApplicationDate, JobId) = line
        job_info[JobId][3] += 1

print ("Sorting jobs on based on popularity...")
top_city_jobs = ddict(lambda: ddict(lambda: ddict(list)))
top_state_jobs = ddict(lambda: ddict(list))
for (job_id, (window, State, City, count)) in job_info.items():
    top_city_jobs[window][State][City].append((job_id, count))
    top_state_jobs[window][State].append((job_id, count))
for window in [1, 2, 3, 4, 5, 6, 7]:
    for state in top_city_jobs[window]:
        for city in top_city_jobs[window][state]:
            top_city_jobs[window][state][city].sort(key=lambda x: x[1])
            top_city_jobs[window][state][city].reverse()
    for state in top_state_jobs[window]:
        top_state_jobs[window][state].sort(key=lambda x: x[1])
        top_state_jobs[window][state].reverse()

print( "Making predictions...")
with open(wd + "users.tsv", "r") as infile:
    reader = csv.reader(infile, delimiter="\t", 
    quoting=csv.QUOTE_NONE, quotechar="")
    next(reader)  # burn the header
    with open(wd + "popular_jobs.csv", "w") as outfile:
        outfile.write("UserId, JobIds\n")
        for line in reader:
            (UserId, WindowId, Split, City, State, Country, ZipCode,
            DegreeType, Major, GraduationDate, WorkHistoryCount,
            TotalYearsExperience, CurrentlyEmployed, ManagedOthers,
            ManagedHowMany) = line
            if Split == "Train":
                continue
            top_jobs = top_city_jobs[int(WindowId)][State][City]
            if len(top_jobs) < 150:
                top_jobs += top_state_jobs[int(WindowId)][State]
            top_jobs = top_jobs[0:150]
            outfile.write(str(UserId) + "," + " ".join([x[0] for x in top_jobs]) + "\n")
# Out:
# Recording job locations...
# Counting applications...
# Sorting jobs on based on popularity...
# Making predictions...

# %%
data[0]["Title"]
# Out:
# 'Security Engineer/Technical Lead'

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)

# %%
df.head(20)
# Out:
#    Jobid WindowId                                        Title  \
# 0      1        1             Security Engineer/Technical Lead
# 1      4        1                    SAP Business Analyst / WM
# 2      7        1                P/T HUMAN RESOURCES ASSISTANT
# 3      8        1                       Route Delivery Drivers
# 4      9        1                                 Housekeeping
# 5     10        1                        SALON/SPA COORDINATOR
# 6     11        1                               SUPERINTENDENT
# 7     12        1            ELECTRONIC PRE-PRESS PROFESSIONAL
# 8     13        1  UTILITY LINE TRUCK OPERATOR/ DIGGER DERRICK
# 9     14        1        CONSTRUCTION PROJECT MGR & PM TRAINEE
# 10    15        1                     Administrative Assistant
# 11    16        1                           ACCOUNT EXECUTIVES
# 12    17        1                         COMMERCIAL ESTIMATOR
# 13    18        1                            Immediate Opening
# 14    19        1                                 TESL Adjunct
# 15    20        1                   Salon Manager/Hairstylists
# 16    21        1                         VOCATIONAL COUNSELOR
# 17    22        1                      GALLERY SALES POSITIONS
# 18    23        1                          SURGICAL SCRUB TECH
# 19    24        1                            Real Estate Agent
#
#                                           Description  \
# 0   <p>Security Clearance Required:&nbsp; Top Secr...
# 1   <strong>NO Corp. to Corp resumes&nbsp;are bein...
# 2   <b>    <b> P/T HUMAN RESOURCES ASSISTANT</b> <...
# 3   CITY BEVERAGES Come to work for the best in th...
# 4   I make  sure every part of their day is magica...
# 5   <b>    <b>— SALON/SPA COORDINATOR             ...
# 6   <b>    <b>SUPERINTENDENT</b> </b>  ——  Central...
# 7   <b>    <b>ELECTRONIC PRE-PRESS PROFESSIONAL</b...
# 8   <b>     </b> \r\n <b>    <b>UTILITY LINE TRUCK...
# 9   <b>    <b>CONSTRUCTION PROJECT MGR </b> </b> \...
# 10  This Administrative Assistant position is resp...
# 11  <b>    <b>ACCOUNT EXECUTIVES</b> </b>  ——  Imm...
# 12  <b>    <b>TRI-CITY ELECTRICAL CONTRACTORS, INC...
# 13  Immediate Opening - AR Clerk is needed  foward...
# 14  TESL Adjunct - The Embry-Riddle Language Insti...
# 15  Salon Manager/Hairstylists - Macys Oviedo Mall...
# 16  <b>    <b>VOCATIONAL COUNSELOR</b> </b>  ——  R...
# 17  <b>    <b>         GALLERY SALES POSITIONS    ...
# 18  <b>    <b> SURGICAL SCRUB TECH </b> </b>  —— V...
# 19  Now accepting Seasoned Agents who want to earn...
#
#                                          Requirements               City  \
# 0   <p>SKILL SET</p>\r<p>&nbsp;</p>\r<p>Network Se...         Washington
# 1   <p><b>WHAT YOU NEED: </b></p>\r<p>Four year co...          Charlotte
# 2   Please refer to the Job Description to view th...        Winter Park
# 3   Please refer to the Job Description to view th...            Orlando
# 4   Please refer to the Job Description to view th...            Orlando
# 5   Please refer to the Job Description to view th...       Ormond Beach
# 6   Please refer to the Job Description to view th...            Orlando
# 7   Please refer to the Job Description to view th...            Orlando
# 8   Please refer to the Job Description to view th...            Orlando
# 9   Please refer to the Job Description to view th...        Winter Park
# 10  Please refer to the Job Description to view th...        Los Angeles
# 11  Please refer to the Job Description to view th...           Longwood
# 12  Please refer to the Job Description to view th...  Altamonte Springs
# 13  Please refer to the Job Description to view th...            Orlando
# 14  Please refer to the Job Description to view th...      Daytona Beach
# 15  Please refer to the Job Description to view th...             Oviedo
# 16  Please refer to the Job Description to view th...            Orlando
# 17  Please refer to the Job Description to view th...            Orlando
# 18  Please refer to the Job Description to view th...  Altamonte Springs
# 19  Please refer to the Job Description to view th...         Windermere
#
#    State Country   Zip5                StartDate              EndDate
# 0     DC      US  20531  2012-03-07 13:17:01.643  2012-04-06 23:59:59
# 1     NC      US  28217  2012-03-21 02:03:44.137  2012-04-20 23:59:59
# 2     FL      US  32792  2012-03-02 16:36:55.447  2012-04-01 23:59:59
# 3     FL      US         2012-03-03 09:01:10.077  2012-04-02 23:59:59
# 4     FL      US          2012-03-03 09:01:11.88  2012-04-02 23:59:59
# 5     FL      US  32174  2012-03-05 14:21:50.203  2012-04-04 23:59:59
# 6     FL      US  32801   2012-03-06 09:21:54.58  2012-04-05 23:59:59
# 7     FL      US  32808   2012-03-06 11:21:53.63  2012-04-05 23:59:59
# 8     FL      US  32801  2012-03-06 16:06:53.677  2012-04-05 23:59:59
# 9     FL      US  32789  2012-03-07 10:21:37.467  2012-04-06 23:59:59
# 10    CA      US  90011   2012-03-09 01:12:16.81  2012-04-08 23:59:59
# 11    FL      US  32779  2012-03-08 05:09:42.803  2012-04-07 23:59:59
# 12    FL      US  32714  2012-03-08 11:07:05.733  2012-04-07 23:59:59
# 13    FL      US  32819  2012-03-10 01:13:29.223  2012-04-09 23:59:59
# 14    FL      US  32114  2012-03-10 01:13:30.193  2012-04-09 23:59:59
# 15    FL      US  32765   2012-03-10 01:13:29.93  2012-04-09 23:59:59
# 16    FL      US  32804  2012-03-09 16:21:56.203  2012-04-08 23:59:59
# 17    FL      US  32819  2012-03-09 16:51:56.403  2012-04-08 23:59:59
# 18    FL      US  32701   2012-03-09 17:06:45.98  2012-04-08 23:59:59
# 19    FL      US  34786   2012-03-10 01:13:30.43  2012-04-09 23:59:59
